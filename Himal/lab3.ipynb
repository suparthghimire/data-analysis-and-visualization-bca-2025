# %% [markdown]
# # Lab 3: Different Types of data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/AirIndia.csv')

df.columns = [col.strip().replace('\n','') for col in df.columns]

# %%
# Nominal Data
nominal = df['Month']

plt.figure(figsize=(8,5))
nominal.value_counts().plot(kind='bar', color='skyblue')
plt.title('Nominal Data: Month - Bar Chart')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(6,6))
nominal.value_counts().plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Nominal Data: Month - Pie Chart')
plt.ylabel('')
plt.show()

# %%
# Ordinal Data
ordinal = df['FY']

ordinal_counts = ordinal.value_counts().sort_index()
plt.figure(figsize=(8,5))
ordinal_counts.plot(kind='bar', color='salmon')
plt.title('Ordinal Data: Financial Year - Ordered Bar Chart')
plt.xlabel('Financial Year')
plt.ylabel('Count')
plt.show()

# %%
# Interval Data
interval = df['PAX. LOAD FACTOR#(IN %)'].astype(float)

plt.figure(figsize=(8,5))
plt.plot(df['Month'], interval, marker='o', linestyle='-', color='purple')
plt.title('Interval Data: PAX LOAD FACTOR (%) - Line Chart')
plt.xlabel('Month')
plt.ylabel('Load Factor %')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(8,5))
sns.barplot(x=df['Month'], y=interval, palette='coolwarm')
plt.title('Interval Data: PAX LOAD FACTOR (%) - Bar Chart')
plt.xlabel('Month')
plt.ylabel('Load Factor %')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Himal\AppData\Local\Temp\ipykernel_4420\3553152608.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Month'], y=interval, palette='coolwarm')

# %%
ratio_cols = ['DEPARTURES', 'HOURS', 'KILOMETER(TH)', 'PASSENGERS CARRIED',
              'PASSENGER KMS. PERFORMED(TH)', 'AVAILABLE SEAT KILOMETRE(TH)']

for col in ratio_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

plt.figure(figsize=(10,6))
sns.scatterplot(x='Month', y='PASSENGERS CARRIED', data=df, color='green', s=100)
plt.title('Ratio Data: Passengers Carried - Scatter Plot')
plt.xlabel('Month')
plt.ylabel('Passengers Carried')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='Month', y='DEPARTURES', data=df, palette='viridis')
plt.title('Ratio Data: Departures - Bar Chart')
plt.xlabel('Month')
plt.ylabel('Number of Departures')
plt.xticks(rotation=45)
plt.show()

sns.lmplot(x='PASSENGERS CARRIED', y='PASSENGER KMS. PERFORMED(TH)', data=df, aspect=1.5)
plt.title('Ratio Data: Passengers Carried vs Passenger KMS - Lollipop/Slope Chart')
plt.xlabel('Passengers Carried')
plt.ylabel('Passenger KMS Performed (TH)')
plt.show()
# Out:
# C:\Users\Himal\AppData\Local\Temp\ipykernel_4420\3687557693.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Month', y='DEPARTURES', data=df, palette='viridis')
